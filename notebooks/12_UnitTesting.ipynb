# %% [markdown]
# # Step 12: Run Your Code End-to-End with Logging and Testing

# %% [markdown]
# <li>Used Visual Studio Code Editor as IDE</li>
# <li>Used Github as code repository</li>
# <li>Enabled Pylint for ensuring Coding standards</li>
# <li>Used “unittest” module for Unit testing</li>
# <li>Used “coverage” for validating code coverage by Unit Tests</li>
# <li>Enabled logging for all 3 modules. Sample log attached in /logs directory</li>
# <li>Used AWS Beanstalk for deployment of Flask Web App</li>

# %% [markdown]
# ## Unit Testing results

# %% [markdown]
# Please find below, Unit testing coverage report for all the 3 modules used in project.
#
# As per above results, the code coverage is <code style="background:yellow">>90%</code> across all the modules.

# %% [markdown]
# ### Collector

# %% [markdown]
# ![ut_collector.png](attachment:ut_collector.png)

# %% [markdown]
# ### Analyzer

# %% [markdown]
# ![ut_analyzer.png](attachment:ut_analyzer.png)

# %% [markdown]
# ### Flask Web App

# %% [markdown]
# ![ut_app.png](attachment:ut_app.png)
